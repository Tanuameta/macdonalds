# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
sns.set_style(style='darkgrid')
warnings.filterwarnings('ignore')

# %%
import os

# %%
os.chdir("C:\\Users\\TANUPRIYA\\Desktop\\jupytercsv_file")

# %%
df=pd.read_csv("macdonald.csv")

# %%
df
# Out:
#   yummy convenient spicy fattening greasy  fast  cheap tasty expensive  \
# 0    No        yes    No       yes      No   yes   yes    No       yes
# 1   yes        yes    No       yes     yes   yes   yes   yes       yes
# 2    No        yes   yes       yes     yes   yes    no   yes       yes
# 3   yes        yes    no       yes     yes   yes   yes   yes        no
# 4    No        yes    No       yes     yes   yes   yes    no        no
#
#   healthy disgustinglike    like  age      visitfrequency  Unnamed: 14  gender
# 0      no             no      -3   61  every three months          NaN  female
# 1      no             no       2   51  every three months          NaN  female
# 2     yes             no       1   62  every three months          NaN  female
# 3      no            yes       4   69        once a  week          NaN  female
# 4     yes             no       2   49        once a month          NaN    male

# %%
df.shape
# Out:
# (5, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   yummy           5 non-null      object
#  1   convenient      5 non-null      object
#  2   spicy           5 non-null      object
#  3   fattening       5 non-null      object
#  4   greasy          5 non-null      object
#  5   fast            5 non-null      object
#  6   cheap           5 non-null      object
#  7   tasty           5 non-null      object
#  8   expensive       5 non-null      object
#  9   healthy         5 non-null      object
#  10  disgustinglike  5 non-null      object
#  11    like          5 non-null      int64
#  12  age             5 non-null      int64
#  13  visitfrequency  5 non-null      object
#  14  Unnamed: 14     0 non-null      float64
#  15  gender          5 non-null      object
# dtypes: float64(1), int64(2), object(13)
# memory usage: 768.0+ bytes

# %%
df.head()
# Out:
#   yummy convenient spicy fattening greasy  fast  cheap tasty expensive  \
# 0    No        yes    No       yes      No   yes   yes    No       yes
# 1   yes        yes    No       yes     yes   yes   yes   yes       yes
# 2    No        yes   yes       yes     yes   yes    no   yes       yes
# 3   yes        yes    no       yes     yes   yes   yes   yes        no
# 4    No        yes    No       yes     yes   yes   yes    no        no
#
#   healthy disgustinglike    like  age      visitfrequency  Unnamed: 14  gender
# 0      no             no      -3   61  every three months          NaN  female
# 1      no             no       2   51  every three months          NaN  female
# 2     yes             no       1   62  every three months          NaN  female
# 3      no            yes       4   69        once a  week          NaN  female
# 4     yes             no       2   49        once a month          NaN    male

# %%
df['yummy'].nunique()
# Out:
# 2

# %%
df.isnull().sum()
# Out:
# yummy             0
# convenient        0
# spicy             0
# fattening         0
# greasy            0
# fast              0
# cheap             0
# tasty             0
# expensive         0
# healthy           0
# disgustinglike    0
#   like            0
# age               0
# visitfrequency    0
# Unnamed: 14       5
# gender            0
# dtype: int64

# %%
df['gender'].nunique()
# Out:
# 2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   yummy           5 non-null      object
#  1   convenient      5 non-null      object
#  2   spicy           5 non-null      object
#  3   fattening       5 non-null      object
#  4   greasy          5 non-null      object
#  5   fast            5 non-null      object
#  6   cheap           5 non-null      object
#  7   tasty           5 non-null      object
#  8   expensive       5 non-null      object
#  9   healthy         5 non-null      object
#  10  disgustinglike  5 non-null      object
#  11    like          5 non-null      int64
#  12  age             5 non-null      int64
#  13  visitfrequency  5 non-null      object
#  14  Unnamed: 14     0 non-null      float64
#  15  gender          5 non-null      object
# dtypes: float64(1), int64(2), object(13)
# memory usage: 768.0+ bytes

# %%
df.head()
# Out:
#   yummy convenient spicy fattening greasy  fast  cheap tasty expensive  \
# 0    No        yes    No       yes      No   yes   yes    No       yes
# 1   yes        yes    No       yes     yes   yes   yes   yes       yes
# 2    No        yes   yes       yes     yes   yes    no   yes       yes
# 3   yes        yes    no       yes     yes   yes   yes   yes        no
# 4    No        yes    No       yes     yes   yes   yes    no        no
#
#   healthy disgustinglike    like  age      visitfrequency  Unnamed: 14  gender
# 0      no             no      -3   61  every three months          NaN  female
# 1      no             no       2   51  every three months          NaN  female
# 2     yes             no       1   62  every three months          NaN  female
# 3      no            yes       4   69        once a  week          NaN  female
# 4     yes             no       2   49        once a month          NaN    male

# %%
df.describe()
# Out:
#            like        age  Unnamed: 14
# count  5.000000   5.000000          0.0
# mean   1.200000  58.400000          NaN
# std    2.588436   8.294577          NaN
# min   -3.000000  49.000000          NaN
# 25%    1.000000  51.000000          NaN
# 50%    2.000000  61.000000          NaN
# 75%    2.000000  62.000000          NaN
# max    4.000000  69.000000          NaN

# %%
df.disgustinglike.count()
# Out:
# 5

# %%
pd.get_option("display.max_columns")
# Out:
# 20

# %%
pd.set_option("display.max_columns", None)
df.head()
# Out:
#   yummy convenient spicy fattening greasy  fast  cheap tasty expensive  \
# 0    No        yes    No       yes      No   yes   yes    No       yes
# 1   yes        yes    No       yes     yes   yes   yes   yes       yes
# 2    No        yes   yes       yes     yes   yes    no   yes       yes
# 3   yes        yes    no       yes     yes   yes   yes   yes        no
# 4    No        yes    No       yes     yes   yes   yes    no        no
#
#   healthy disgustinglike    like  age      visitfrequency  Unnamed: 14  gender
# 0      no             no      -3   61  every three months          NaN  female
# 1      no             no       2   51  every three months          NaN  female
# 2     yes             no       1   62  every three months          NaN  female
# 3      no            yes       4   69        once a  week          NaN  female
# 4     yes             no       2   49        once a month          NaN    male
